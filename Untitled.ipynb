# %%
import numpy as np
import pandas as pd

# %%
Details=pd.read_csv('titanic_data.csv')

# %%
Details.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Number_of_people=Details['Survived'].count()
Number_of_people
# Out:
# 891

# %%
Details.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
Survive=Details[Details.Survived==1]
Number_of_survive=len(Survive)
Number_of_survive
# Out:
# 342

# %%
Percentage_of_survive=(Number_of_survive/Number_of_people)*100
Percentage_of_survive
# Out:
# 38.383838383838381

# %%
Survive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
Survive.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               136       136   136  136  122    136    136     136   136
# 2                87        87    87   87   83     87     87      87    87
# 3               119       119   119  119   85    119    119     119   119
#
#         Cabin  Embarked
# Pclass
# 1         117       134
# 2          13        87
# 3           6       119

# %%
Survive.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          233       233     233   233  197    233    233     233   233
# male            109       109     109   109   93    109    109     109   109
#
#         Cabin  Embarked
# Sex
# female     91       231
# male       45       109

# %%
Survive.groupby('SibSp').count()
# Out:
#        PassengerId  Survived  Pclass  Name  Sex  Age  Parch  Ticket  Fare  \
# SibSp
# 0              210       210     210   210  210  175    210     210   210
# 1              112       112     112   112  112   97    112     112   112
# 2               13        13      13    13   13   11     13      13    13
# 3                4         4       4     4    4    4      4       4     4
# 4                3         3       3     3    3    3      3       3     3
#
#        Cabin  Embarked
# SibSp
# 0         77       208
# 1         52       112
# 2          5        13
# 3          2         4
# 4          0         3

# %%
Survive.groupby('Parch').count()
# Out:
#        PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Ticket  Fare  \
# Parch
# 0              233       233     233   233  233  186    233     233   233
# 1               65        65      65    65   65   61     65      65    65
# 2               40        40      40    40   40   39     40      40    40
# 3                3         3       3     3    3    3      3       3     3
# 5                1         1       1     1    1    1      1       1     1
#
#        Cabin  Embarked
# Parch
# 0         91       231
# 1         28        65
# 2         17        40
# 3          0         3
# 5          0         1

# %%
Survive.groupby('Embarked').count()
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# C                  93        93      93    93   93   79     93     93      93
# Q                  30        30      30    30   30    8     30     30      30
# S                 217       217     217   217  217  201    217    217     217
#
#           Fare  Cabin
# Embarked
# C           93     52
# Q           30      2
# S          217     80

# %%
''' There were 891 people. Out of which only 342 are alive (so survival rate is 38.38%). 
Those who are staying in P1 and P3 are likely to survive.Moreover those who are alone(like no spouse,sibling,parent or children)
are likely to survive more than others.Moreover those who have port is S are likely to survive more in comparison to others'''
# Out:
# ' There were 891 people. Out of which only 342 are alive (so survival rate is 38.38%). \nThose who are staying in P1 and P3 are likely to survive.Moreover those who are alone(like no spouse,sibling,parent or children)\nare likely to survive more than others.Moreover those who have port is S are likely to survive more in comparison to others'

# %%
''' So factors of Survival is 1) Pclass 2) SibSp and Parch 3)Female 4) Port of embarked'''

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
Survive.groupby('Embarked').plot()
# Out:
# Embarked
# C    AxesSubplot(0.125,0.125;0.775x0.755)
# Q    AxesSubplot(0.125,0.125;0.775x0.755)
# S    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
